# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
#
# In this notebook, we will explore some of the key tools, languages, and libraries used in the field of Data Science. We'll also perform simple arithmetic operations and demonstrate basic Python functionality.m

# %% [markdown]
# ## Languages Used in Data Science
#
# Some of the popular languages used by Data Scientists include:
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Popular Data Science Libraries
#
# Here are some important libraries used in Data Science:
#
# - Pandas
# - NumPy
# - Scikit-learn
# - TensorFlow
# - Matplotlib

# %% [markdown]
# ## Data Science Tools
#
# | Tool           | Description                      |
# |----------------|----------------------------------|
# | Jupyter Notebook | Interactive coding environment |
# | RStudio         | IDE for R                        |
# | Apache Spark    | Big data processing framework   |
# | VS Code         | Lightweight code editor         |

# %% [markdown]
# ## Examples of Arithmetic Expressions
#
# Below we will see how to use arithmetic expressions in Python to perform calculations.

# %%
# This expression multiplies 3 and 4, then adds 5
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# Convert 200 minutes to hours
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
#
# - List popular languages in Data Science
# - List commonly used libraries
# - Create tables in Markdown
# - Perform basic arithmetic using Python
# - Convert time units using Python

# %% [markdown]
# ## Author
#
# **Mohamed Omer**
